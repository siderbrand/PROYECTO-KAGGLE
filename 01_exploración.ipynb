# %% [markdown]
# <a href="https://colab.research.google.com/github/siderbrand/PROYECTO-KAGGLE/blob/main/01_exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center"><img alt="udeA logo" height="150px" src="https://github.com/freddyduitama/images/blob/master/logo.png?raw=true"></p><h1><font color='0B5345'> <center>
#
# </center></font></h1>
# <center>
# INTRODUCCION A LA INTELIGENIA ARTIFICIAL
#
#  </center></font></h1>
# <h2><font color='0B5345'> <center>
# PROYECTO KAGGLE</center></font></h2>
# <font  face="Courier New" size="3">
#
# <p3><center><b><font color='0B5345' face="Lucida Calligraphy,Comic Sans MS,Lucida Console" size="5">Universidad de Antioquia</font></b> </center></p3>
#
# <p3><center><b><font> Juan Andres Toro Acevedo - Bioingenieria
# <p3><center><b><font> Eliana María Brand Agudelo - Ingenieria en Sistemas
# <p3><center><b><font> Claudia Rocha - Ingenieria en Sistemas

# %% [markdown]
# ### **ANÁLSIS EXPLORATORIO DE DATOS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np
from tabulate import tabulate
from scipy import stats
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
df_procol = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Introduccion IA/train.csv', sep=',')
df_procol
# Out:
#             ID  PERIODO_ACADEMICO            E_PRGM_ACADEMICO  \
# 0       904256              20212                  ENFERMERIA
# 1       645256              20212                     DERECHO
# 2       308367              20203       MERCADEO Y PUBLICIDAD
# 3       470353              20195  ADMINISTRACION DE EMPRESAS
# 4       989032              20212                  PSICOLOGIA
# ...        ...                ...                         ...
# 136430  947594              20183                     DERECHO
# 136431  334621              20195       INGENIERIA AGRONOMICA
# 136432  255699              20183       ADMINISTRACION HUMANA
# 136433  465846              20195        INGENIERIA AMBIENTAL
# 136434  452045              20203                FISIOTERAPIA
#
#        E_PRGM_DEPARTAMENTO               E_VALORMATRICULAUNIVERSIDAD  \
# 0                   BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1                ATLANTICO  Entre 2.5 millones y menos de 4 millones
# 2                   BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 3                SANTANDER  Entre 4 millones y menos de 5.5 millones
# 4                ANTIOQUIA  Entre 2.5 millones y menos de 4 millones
# ...                    ...                                       ...
# 136430               CESAR  Entre 2.5 millones y menos de 4 millones
# 136431                META         Entre 500 mil y menos de 1 millón
# 136432           ANTIOQUIA    Entre 1 millón y menos de 2.5 millones
# 136433     NORTE SANTANDER         Entre 500 mil y menos de 1 millón
# 136434           ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
#
#        E_HORASSEMANATRABAJA F_ESTRATOVIVIENDA F_TIENEINTERNET  \
# 0         Menos de 10 horas         Estrato 3              Si
# 1                         0         Estrato 3              No
# 2           Más de 30 horas         Estrato 3              Si
# 3                         0         Estrato 4              Si
# 4       Entre 21 y 30 horas         Estrato 3              Si
# ...                     ...               ...             ...
# 136430                    0         Estrato 3              Si
# 136431      Más de 30 horas               NaN              Si
# 136432  Entre 21 y 30 horas         Estrato 3              Si
# 136433  Entre 11 y 20 horas         Estrato 1              Si
# 136434                    0         Estrato 4              Si
#
#                           F_EDUCACIONPADRE F_TIENELAVADORA  ...  \
# 0         Técnica o tecnológica incompleta              Si  ...
# 1           Técnica o tecnológica completa              Si  ...
# 2       Secundaria (Bachillerato) completa              Si  ...
# 3                                  No sabe              Si  ...
# 4                        Primaria completa              Si  ...
# ...                                    ...             ...  ...
# 136430  Secundaria (Bachillerato) completa              Si  ...
# 136431                 Primaria incompleta              Si  ...
# 136432      Técnica o tecnológica completa              Si  ...
# 136433                   Primaria completa              Si  ...
# 136434                        Secundaria (             NaN  ...
#
#        E_PRIVADO_LIBERTAD E_PAGOMATRICULAPROPIO F_TIENECOMPUTADOR  \
# 0                       N                    No                Si
# 1                       N                    No                Si
# 2                       N                    No                No
# 3                       N                    No                Si
# 4                       N                    No                Si
# ...                   ...                   ...               ...
# 136430                  N                    No                Si
# 136431                  N                    Si                Si
# 136432                  N                    Si                Si
# 136433                  N                    No                Si
# 136434                NaN                   NaN               NaN
#
#        F_TIENEINTERNET.1                      F_EDUCACIONMADRE  \
# 0                     Si                             Postgrado
# 1                     No      Técnica o tecnológica incompleta
# 2                     Si    Secundaria (Bachillerato) completa
# 3                     Si    Secundaria (Bachillerato) completa
# 4                     Si                     Primaria completa
# ...                  ...                                   ...
# 136430                Si                               No sabe
# 136431                Si  Secundaria (Bachillerato) incompleta
# 136432                Si  Secundaria (Bachillerato) incompleta
# 136433                Si                   Primaria incompleta
# 136434               NaN                                   NaN
#
#        RENDIMIENTO_GLOBAL INDICADOR_1  INDICADOR_2  INDICADOR_3  INDICADOR_4
# 0              medio-alto       0.322        0.208        0.310        0.267
# 1                    bajo       0.311        0.215        0.292        0.264
# 2                    bajo       0.297        0.214        0.305        0.264
# 3                    alto       0.485        0.172        0.252        0.190
# 4              medio-bajo       0.316        0.232        0.285        0.294
# ...                   ...         ...          ...          ...          ...
# 136430         medio-alto       0.293        0.232        0.306        0.292
# 136431               bajo       0.000        0.044        0.044        0.043
# 136432         medio-bajo       0.318        0.209        0.302        0.290
# 136433         medio-alto       0.136        0.393        0.220        0.300
# 136434                NaN         NaN          NaN          NaN          NaN
#
# [136435 rows x 21 columns]

# %%
conteo_programa = df_procol['E_PRGM_ACADEMICO'].value_counts()

print("--- Top 5 Programas Académicos (E_PRGM_ACADEMICO	) ---")
print(conteo_programa.head(5))

plt.figure(figsize=(5, 6))
conteo_programa.head(5).plot(kind='bar', color='skyblue')
plt.title('Estudiantes por Programa (Top 5)')
plt.xlabel('Programa Académico')
plt.ylabel('Número de Estudiantes')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# --- Top 5 Programas Académicos (E_PRGM_ACADEMICO	) ---
# E_PRGM_ACADEMICO
# DERECHO                       10596
# ADMINISTRACION DE EMPRESAS    10141
# CONTADURIA PUBLICA             7753
# PSICOLOGIA                     6260
# INGENIERIA INDUSTRIAL          5639
# Name: count, dtype: int64
